# %% [markdown]
# ## Exercício
#
# Você é um engenheiro de produção e tem os tempos de ciclo (em minutos) de uma linha de produção em um array NumPy. Seu trabalho é identificar quaisquer tempos de ciclo que estão dois desvios padrão acima ou abaixo da média. Use o seguinte array para sua análise: `tempos_ciclo = np.array([5.5, 5.7, 5.9, 6.0, 5.8, 5.6, 5.7, 7.2, 4.8])`.

# %%
import numpy as np

tempos_ciclo = np.array([5.5, 5.7, 5.9, 6.0, 5.8, 5.6, 5.7, 7.2, 4.8])
media = np.mean(tempos_ciclo) 
desvio_padrao = np.std(tempos_ciclo)

print(media)
print(desvio_padrao)
# Out:
# 5.8
# 0.592546294487706

# %%
# tentei assim, deu erro
# valores_fora_do_padrao = tempos_ciclo > (media + (desvio_padrao * 2)) | tempos_ciclo < (media - (desvio_padrao * 2))
# print(tempos_ciclo)
# print(valores_fora_do_padrao)
# TypeError: ufunc 'bitwise_or' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# pedi ajuda da IA, faltou parênteses
fora_padrao = (tempos_ciclo > (media + (desvio_padrao * 2))) | (tempos_ciclo < (media - (desvio_padrao * 2)))
# printando array dos tempos
print("Tempos de ciclos")
print(tempos_ciclo)

# média 
print(f"Média: {media:.2f}")

# desvio padrão
print(f"Desvio padrão: {desvio_padrao:.2f}")

# printando verdadeiro ou falso para cada elemento fora do padrão
print(fora_padrao)
# printando valores fora do padrão
print("\nTempos fora do padrão: ")
print(tempos_ciclo[fora_padrao])
# Out:
# Tempos de ciclos
# [5.5 5.7 5.9 6.  5.8 5.6 5.7 7.2 4.8]
# Média: 5.80
# Desvio padrão: 0.59
# [False False False False False False False  True False]
#
# Tempos fora do padrão:
# [7.2]

# %%
# tentei assim, mas não sei se tá certo
# pedi ajuda da IA, tava certo sim :D
valores_acima = tempos_ciclo > (media + (desvio_padrao * 2)) 
valores_abaixo = tempos_ciclo < (media - (desvio_padrao * 2)) 
print("\nValores acima do padrão")
print(tempos_ciclo[valores_acima])
print("\nValores abaixo do padrão")
print(tempos_ciclo[valores_abaixo])
# Out:
# Valores acima do padrão
# [7.2]
#
# Valores abaixo do padrão
# []
